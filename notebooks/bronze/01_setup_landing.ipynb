# %% [markdown]
# # Hospital Analytics POC
#
# ## Notebook: 01_setup_landing
#
# ### Purpose
# This notebook prepares the Landing Area for the Hospital Analytics project.
#
# ### Activities
#
# - Create the DBFS landing folder
# - Verify the folder exists
# - No data ingestion
# - No transformations
# - No Delta tables

# %%
# Create the Landing folder in DBFS

dbutils.fs.mkdirs("dbfs:/FileStore/hospital_analytics/raw/")
